# %% [markdown]
# #Find Mid of the linkedlist

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


node1 = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)

node1.next = node2
node2.next = node3
node3.next = node4
#node4.next = node5

head = node1
curr1 = head
curr2 = head

while curr2 and curr2.next:
    curr1 = curr1.next
    curr2 = curr2.next.next

print(curr1.data)

# %%
print(node1.data)
print(node1.next)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


node1 = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

head = node1

curr = head.next

temp = head
prev = head
head.next = None
prev = head
while temp:
    temp = curr.next
   
    curr.next  = prev
    print("curr : ", curr.data)
    print("prev1 : ", prev.data)
    prev = curr
    print("prev : ", prev.data)
    curr = temp


head = prev





#1234
# Out:
# curr :  2
# prev1 :  1
# prev :  2
# curr :  3
# prev1 :  2
# prev :  3
# curr :  4
# prev1 :  3
# prev :  4
# curr :  5
# prev1 :  4
# prev :  5

# %%
while head:

    print(head.data)
    head = head.next
    
#     curr1 = curr

# print(curr1.data)
# Out:
# 5
# 4
# 3
# 2
# 1
